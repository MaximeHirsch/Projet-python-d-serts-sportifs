# %%
import numpy as np
import numpy.linalg as al
import matplotlib.pyplot as plt 
import pandas as pd
from cartiflette import carti_download

url = "https://data.sports.gouv.fr/api/explore/v2.1/catalog/datasets/equipements-sportifs/exports/csv?lang=fr&timezone=Europe%2FBerlin&use_labels=true&delimiter=%3B"
equipement = pd.read_csv(url, sep=";", low_memory=False)
equipement.head(2)
# Out:
#   Numéro de l'équipement sportif Numéro de l'installation sportive  \
# 0                 E001I710760025                        I710760025
# 1                 E001I710760028                        I710760028
#
#   Date de l'enquête   Nom de l'installation sportive SIRET Installation  \
# 0        2025-03-31          Salle de billard Gambey                NaN
# 1        2025-03-31  Espace nautique du grand chalon                NaN
#
#                 Adresse  Code Postal       Commune nom Commune INSEE  \
# 0  9 Impasse du Carloup      71100.0  Chalon-sur-Saône         71076
# 1       Rue d'Amsterdam      71100.0  Chalon-sur-Saône         71076
#
#   Type de particularité de l'installation  ...  \
# 0                                     NaN  ...
# 1                                     NaN  ...
#
#   Accessibilité aux personnes en situation de handicap sensoriel aux tribunes  \
# 0                                              False
# 1                                              False
#
#   Accessibilité aux personnes en situation de handicap sensoriel aux vestiaires  \
# 0                                              False
# 1                                              False
#
#   Longitude  Latitude Type de particularité de l'installation (brute)  \
# 0   4.85658  46.78668                                             NaN
# 1   4.86689  46.78511                                             NaN
#
#                                            Activités  QPV  QPV à 200 mètres  \
# 0  Billard (Français (carambole),Snooker,Anglais,...  NaN               NaN
# 1  Aquagym,Baignade loisirs,Plongée subaquatique ...  NaN               NaN
#
#      Catégorie gen_2024Fin_Labellisation
# 0          NaN                       NaN
# 1  structurant                       NaN
#
# [2 rows x 117 columns]
